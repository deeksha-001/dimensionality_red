# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
# Out:
# c:\Users\deeks\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("data/data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    str
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop("Unnamed: 32", axis=1, inplace=True)

# %%
df.drop("id", axis=1, inplace=True)

# %%
encoder = LabelEncoder()
df["diagnosis"] = encoder.fit_transform(df["diagnosis"])

# %%
df["diagnosis"].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
X = df.drop("diagnosis", axis=1)

y = df["diagnosis"]

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled.mean()
# Out:
# np.float64(-6.53516165871914e-17)

# %%
X_scaled.std()
# Out:
# np.float64(1.0)

# %%
pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

# %%
X_pca.shape
# Out:
# (569, 2)

# %%
pca_df = pd.DataFrame(
    X_pca,
    columns=["PC1", "PC2"]
)

pca_df["Diagnosis"] = y

# %%
pca_df.head()
# Out:
#         PC1        PC2  Diagnosis
# 0  9.192837   1.948583          1
# 1  2.387802  -3.768172          1
# 2  5.733896  -1.075174          1
# 3  7.122953  10.275589          1
# 4  3.935302  -1.948072          1

# %%
pca.explained_variance_ratio_
# Out:
# array([0.44272026, 0.18971182])

# %%
pca.explained_variance_ratio_.sum()
# Out:
# np.float64(0.6324320765155944)

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=pca_df,
    x="PC1",
    y="PC2",
    hue="Diagnosis"
)

plt.title("PCA Visualization")
plt.show()

# %%
pca_full = PCA()

pca_full.fit(X_scaled)
# Out:
# PCA()

# %%
cum_var = np.cumsum(
    pca_full.explained_variance_ratio_
)

# %%
plt.figure(figsize=(8,5))

plt.plot(
    range(1, len(cum_var)+1),
    cum_var,
    marker="o"
)

plt.xlabel("Number of Components")
plt.ylabel("Cumulative Variance")
plt.title("Explained Variance by PCA Components")

plt.grid(True)
plt.show()

# %%
pca_95 = PCA(n_components=0.95)

X_pca_95 = pca_95.fit_transform(X_scaled)

# %%
pca_95.n_components_
# Out:
# np.int64(10)

# %% [markdown]
# 1. Dataset originally contained 30 features.
# 2. Features were standardized using StandardScaler.
# 3. PCA reduced dimensions from 30 to 2.
# 4. The first two principal components retained approximately 63% of the variance.
# 5. Visualization showed clear separation between benign and malignant tumors.
# 6. Around 10 components were sufficient to preserve 95% of the variance.

# %%
import joblib

joblib.dump(scaler, "models/scaler.pkl")
# Out:
# ['models/scaler.pkl']

# %%
joblib.dump(pca, "models/pca.pkl")
# Out:
# ['models/pca.pkl']
